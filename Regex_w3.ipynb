# %%
import re

# %%
txt='The rain in Spain'

# %%
x=re.findall('[a-m]',txt)

# %%
print(set(x))
# Out:
# {'a', 'i', 'h', 'e'}

# %% [markdown]
# Find digit

# %%
txt="that will be 58"

# %%
x=re.findall("\d",txt)

# %%
print(len(x))
# Out:
# 2

# %% [markdown]
# Find word

# %%
txt='hello world'

# %%
x=re.findall("hello",txt)
print(x)
# Out:
# ['hello']

# %%
import re

n=int(input())
for i in range(n):
    s=input()
    print(bool(re.match(r'^[+-]?[0-9]?\.[0-9]+$',s)))
# Out:
# 1
# +.9
# True
