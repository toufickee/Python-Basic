# %%
def frange(start,stop,step):
  i=start
  while i<stop:
    yield i
    i+=step

for i in frange(0.5,1.01,0.1):
  print(i)
# Out:
# 0.5
# 0.6
# 0.7
# 0.7999999999999999
# 0.8999999999999999
# 0.9999999999999999

# %%
def make_sum(*args):
  sum=0
  for num in args:
    sum+=num
  return sum

print(make_sum(10,20,30,40))
# Out:
# 100

# %%
def print_dict(*args):
  print(args)

print_dict(a=1,b=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-dd769c42702d> in <module>()
#       2   print(args)
#       3
# ----> 4 print_dict(a=1,b=2)
#
# TypeError: print_dict() got an unexpected keyword argument 'a'

# %%
def print_dict(**kwargs):
  print(kwargs)

print_dict(a=1,b=2)
# Out:
# {'a': 1, 'b': 2}

# %%
def print_dict(**kwargs):
  for args in kwargs:
    print("{0}:{1}".format(args,kwargs[args]))

print_dict(a=1,b=2,c=3)
# Out:
# a:1
# b:2
# c:3

# %%
def print_all(a,*args,**kwargs):
  print(a)
  print(args)
  print(kwargs)

print_all(10,20,30,50,b=5,c=10)
# Out:
# 10
# (20, 30, 50)
# {'b': 5, 'c': 10}
